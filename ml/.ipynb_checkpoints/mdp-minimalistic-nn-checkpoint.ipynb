# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import numpy as np
import theano
theano.config.floatX = 'float32'
theano.config.openmp = True
import theano.tensor as T
import lasagne
# %load_ext autoreload
# %autoreload 2
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.

# %%
_shared = lambda name,val,dtype: theano.shared(val.astype(dtype),name,
                                               strict = True,allow_downcast=True)
floatX = theano.config.floatX

# %% [markdown]
# # problem statement

# %%
arr_len = 25
n_rules = 15

rule_lengths = np.random.normal(3,2,size=n_rules).astype(int)
rule_lengths[rule_lengths<1] = 1

rule_starts = np.random.randint(0,arr_len-1,size=n_rules)

rules = map(lambda x0,l: np.arange(x0,min(x0+l, arr_len)) , rule_starts, rule_lengths)
rules = np.array(rules)

rule_probas = np.repeat(0.5,n_rules)

# %%
from itertools import product
class Event:
    def __init__(self,arr):
        self.arr = arr
    def respond(self,action_code):
        return self.arr[action_code]

def generate_event():
    rule_triggered = rule_probas > np.random.random(size = n_rules)
    rule_triggered = rule_triggered.astype(bool)
    
    arr = np.zeros(arr_len).astype(bool)
    if np.any(rule_triggered):
        arr[np.concatenate(rules[rule_triggered])] = True
    return Event(arr)

def get_action_codes(event):
    codes = [np.arange(i) for i in event.arr.shape]
    return list(product(*codes)) + [-1] #-1 is "next event" action

# %%
print rules
for i in range(5):
    plt.imshow(generate_event().arr.reshape(-1,5))
    plt.colorbar()
    plt.show()
# Out:
# [array([21]) array([18, 19, 20]) array([21, 22, 23, 24])
#  array([14, 15, 16, 17]) array([23, 24]) array([15, 16]) array([10])
#  array([12, 13, 14, 15]) array([8]) array([4, 5]) array([ 7,  8,  9, 10])
#  array([12, 13, 14, 15]) array([3, 4, 5, 6]) array([ 8,  9, 10, 11])
#  array([18])]
# /usr/lib/pymodules/python2.7/matplotlib/collections.py:548: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':

# %% [markdown]
# # naive q-learning

# %%
TGrad_ignore_list = []

# %%
class PracticeEnvironment:
    def __init__(self,batch_size=10,seq_len=10): 
        """an environment class that defines what does MDP interact with"""
        self._arr = _shared("event_bool_arr",np.zeros([1,arr_len]),'int8')
        self._arr_extended = T.concatenate([self._arr,T.zeros_like(self._arr[:,:1])],axis=1)
        
        
        self.seq_len = seq_len
        self.batch_size = batch_size
        self.n_outputs = 26
        self.n_inputs = 1
        self.generic_input_shape = fake_input_shape = [None,None,1,self.n_inputs]


        
        self._greediness = _shared("greediness",np.float32(1.),floatX)
        self._bag_of_randomness = _shared("randomness",
                                          np.random.random([self.seq_len,self.batch_size]),floatX)
        
        self._shape_input = _shared("fake_inp_var_for_shape",
                                    np.zeros([self.batch_size,self.seq_len,1,self.n_outputs]),floatX)


        self.dependencies = [
            self._arr,
            self._greediness,
            self._bag_of_randomness
        ]
        
        
        self.reset_agent = lambda bs,sl: None
    
    def change_shape(self,batch_size,seq_len):
        self.batch_size = batch_size
        self.seq_len = seq_len
        new_inp_shape = np.zeros([self.batch_size,self.seq_len,1,self.n_inputs],dtype=floatX) 
        self._shape_input.set_value( new_inp_shape)
        
        self.prepare_sessions()
        
    def prepare_sessions(self):
        self.reset_agent(self.batch_size,self.seq_len)
        self.load_next_events()
        self.get_some_randomness()
        
        
    def load_next_events(self):
        
        arrs = np.concatenate([generate_event().arr[None,:].astype('int8')
                               for i in range(self.batch_size)],axis=0)
        
        self._arr.set_value(arrs.reshape(self.batch_size,-1))
        
        
    def get_some_randomness(self):
        """reloads the shared random variable sequences used instead of real-time RNG to avoid problems with
        T.scan updates."""
        randomness_shape = (self.seq_len,self.batch_size)
        self._bag_of_randomness.set_value(
            np.random.random(randomness_shape).astype(floatX))
    
    def get_action_probas(self,hidden_activation):
        exp_x = T.exp(hidden_activation*self._greediness)
        probas = exp_x/exp_x.sum(axis=1,keepdims=True)
        return probas
    
    def decision_by_hidden(self,itr,hidden_activation): #has to be deterministic function
        """take 1D float32 array and return action code.
        Action code must be stackable with hidden_activation
        Do not use random INSIDE. It's okay to pre-generate randomness"""
        
        probas = self.get_action_probas(hidden_activation) #[batch_size,n-actions]
        
        #softmax sampling
        cum_probas = probas.cumsum(axis=1) #[batch_size-1,n-actions]
        
        batch_of_random = self._bag_of_randomness[itr,:] #batch_size of floatX
        batch_of_random = batch_of_random.reshape([-1,1]) 
        
        
        choices = (batch_of_random > cum_probas).sum(axis=1).astype('int32')

        #choices = T.argmax(probas,axis=1) #determinstic maxima
        
        
        return T.extra_ops.to_one_hot(choices,nb_class = self.n_outputs)
        
    def input_by_decision(self,itr,decision): #has to be deterministic function
        """take action code and return the next input observation.
        Do not use random INSIDE. It's okay to pre-generate randomness"""
        
        dec_ids = T.argmax(decision,axis=1)
        TGrad_ignore_list.append(dec_ids)
        
        _regular_response =  self._arr_extended[T.arange(dec_ids.shape[0]),dec_ids]
        
        return T.switch( T.eq(dec_ids ,self.n_outputs-1), 0, _regular_response
                       ).reshape([-1,1])#last 1 is the input shape
        
    def decision_init_factory(self):
        """returns a value for '-1st' action, that is than aligned to the zero-tick
        hidden state"""
        dec0 = np.zeros( self.n_outputs ,dtype=floatX)
        dec0[0] =1
        return dec0
    def on_new_session(self,function):
        """takes a function of (batch_size, input_size) and
        calls it before each new session start"""
        self.reset_agent = function

# %%
from retina.MDPlayer import GRULayer

# %%
env = PracticeEnvironment()

env.change_shape(50,25)
#gotta run this each time you start a new batch.



_nn_inp = lasagne.layers.InputLayer( env.generic_input_shape  ,name="fake_inp_layer",
                                          input_var = env._shape_input)       
_rnn = GRULayer(_nn_inp,env.n_outputs,env,name="mdp_gru")

#init trainer
env.prepare_sessions()

# %%
env._arr_extended.shape.eval()
# Out:
# array([50, 26])

# %%
_prediction = lasagne.layers.get_output(_rnn)
_weights = lasagne.layers.get_all_params(_rnn)
_weights
predict = theano.function([],_prediction,mode=theano.compile.mode.FAST_COMPILE)
# Out:
# called get_output
# /usr/local/lib/python2.7/dist-packages/theano/scan_module/scan.py:1019: Warning: In the strict mode, all neccessary shared variables must be passed as a part of non_sequences
#   'must be passed as a part of non_sequences', Warning)

# %%
#howto run
env.prepare_sessions()

pred_history = predict()
decisions = pred_history[:,:,0,:]
activations = pred_history[:,:,1,:]
plt.hist(activations.ravel(),bins=50)
plt.show()
_= plt.hist(decisions.argmax(-1).ravel(),bins=50)

# %% [markdown]
# # learning

# %%
_prediction.shape.eval()
# Out:
# array([50, 25,  2, 26])

# %%
def get_feedback(_prediction,dependencies=[],t0 = 0, end_code =25,strict = True):
    """computes series of rewards from time step t0.
    Considers end_code as a sign of session end
    Assumes prediction shape to be [batch_id,seq_length,channel,unit]
    dependencies must contain all variables (incl. shared) that prediction depends on
    alternatively, if strict == False, this list can be empty or partial"""
    
    #channel, sequence, batch,unit shape is assumed to than split into two channel variables
    # 2x[sequence,batch,unit] cuz T.scan works along axis 0
    
    _prediction_csbu = _prediction.dimshuffle([2,1,0,3]) 
    
    _predicted_Qvalues = _prediction_csbu[1,t0:,:,:]
    _commited_actions =  _prediction_csbu[0,t0:,:,:].astype('int8')

    _arrays_ext = env._arr_extended #[batch_i,n_hidden]
    
    
    _attempted_init =T.zeros_like(_arrays_ext,dtype='int8') #

    outputs_info = [_attempted_init,
                    T.zeros_like(_prediction[:,0,0,0],dtype='float32'),
                    T.ones_like(_prediction[:,0,0,0],dtype='int8')
                   ]

    non_sequences = [_arrays_ext]
    _commited_action_ids = T.argmax(_commited_actions,-1)
    TGrad_ignore_list.append(_commited_action_ids)
    sequences = [_commited_action_ids]
    
    def reward_computation_step(decision_code,

                                fields_attempted_ext,
                                last_reward,
                                session_active,

                                event_arr_ext,*args):
        """i am used to compute the stepwise reward function via scan
        decision_code - int8 one-hot matrix(batch_i,decision_code_i)
        fields_attempted - int8 matrix (batch_i, array field id)
        last_reward - float32 vector (batch_i) - reward on previous step
        session_active - int8 vector (batch_i) - whether session is still not finished
        event_arr - an array (int8) of game stage"""



        batch_i = T.arange(decision_code.shape[0],dtype='int32')
        ones_batch = T.ones_like(decision_code,dtype=floatX,)
        zeros_batch = T.zeros_like(decision_code,dtype=floatX,)


        #step

        has_finished_now = T.eq(decision_code,end_code)

        session_still_active = session_active*(1-has_finished_now) # array [batch_i] of bool

        is_first_time = T.eq(fields_attempted_ext[batch_i,decision_code],0)

        first_time_reward = (2*event_arr_ext[batch_i,decision_code] -1.).astype(floatX)

        current_reward = T.switch(session_still_active,                                
                                        T.switch(is_first_time,
                                                    first_time_reward,
                                                    -0.5*ones_batch
                                                ),
                                        0.*zeros_batch
                                )

        fields_attempted_now_ext = fields_attempted_ext | T.extra_ops.to_one_hot(
            decision_code,26,).astype('int8')

        #current_reward
        return fields_attempted_now_ext,current_reward,session_still_active

    attempted_ext,rewards,session_is_alive = theano.scan(
                                            reward_computation_step,
                                            sequences,
                                            outputs_info,
                                            non_sequences,
                                            strict=True)[0]
    attempted_ext = attempted_ext[-1]
    
    _commited_actions = _commited_actions.dimshuffle([1,0,2])
    _predicted_Qvalues = _predicted_Qvalues.dimshuffle([1,0,2])
    
    return rewards.T,session_is_alive.T,attempted_ext,\
            _commited_action_ids,_predicted_Qvalues

# %%
def get_reference_triples(_rewards,_isalive,_attempts,_decision_ids,_activations,
                            _gamma = _shared('q_learning_gamma',np.float32(0.99),floatX)
                        ):
    """computes three vectors:
      action IDs (1d,single integer) vector of all actions that were commited during all sequences
      in the batch, concatenated in one vector... that is, excluding the ones that happened
      after the end_code action was sent.
    
      Qpredicted - activations for action_IDs ONLY at each time 
      before sequence end action was committed for each sentence in the batch (concatenated) 
      but for the last time-slot.
      
      Qreference - sum over immediate rewards and gamma*predicted activations for
      next round after first vector predictions"""
    _alive_selector = _isalive[:,:-1].nonzero() # number of: [batch,time] but for (seq_len)-th

    _next_selector = (_isalive[0],_isalive[1]+1) # number of: [batch,time+1]


    # predictions for Qvalues in the order of _alive_selector (id, n_outputs)
    _predicted_Qvalues = _activations[_alive_selector[0],_alive_selector[1]]
    
    #iterator array over all prediction samples
    _event_i = T.arange(_predicted_Qvalues.shape[0])
    # corresponding choices
    _chosen_action_IDs = _decision_ids[_alive_selector,:]
    
    #predictions that resulted in actions
    _tested_predicted_Qvalues = _predicted_Qvalues[_event_i, _chosen_action_IDs]

    # corresponding rewards (immediate)
    _immediate_rewards = _rewards[_alive_selector]
    # corresponding rewards for different next turn actions
    _predicted_next_rewards =_activations[_next_selector]
    
    #best of _predicted_next_rewards for each time
    _optimal_next_rewards = T.max(_predicted_next_rewards,axis=-1)
    TGrad_ignore_list.append(_optimal_next_rewards)

    #full rewards from taking _chosen_action and behaving optimally later on
    _reference_Qvalues = _immediate_rewards + _gamma*_optimal_next_rewards
    return _chosen_action_IDs, _tested_predicted_Qvalues,_reference_Qvalues

# %%
_gamma = _shared('q_learning_gamma',np.float32(0.99),floatX)

_feedback = get_feedback(_prediction,dependencies=env.dependencies,end_code=25)

args = _feedback + (_gamma,)
_action_ids, _predicted_Qvalues, _reference_Qvalues = get_reference_triples(* args)


_loss = lasagne.objectives.squared_error(_predicted_Qvalues,_reference_Qvalues).mean()

# %%
#theano.printing.pydotprint(_loss,'graph.png')

# %%
_loss.eval()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-160-004a64885e9a> in <module>()
# ----> 1 _loss.eval()
#
# /usr/local/lib/python2.7/dist-packages/theano/gof/graph.pyc in eval(self, inputs_to_values)
#     521         args = [inputs_to_values[param] for param in inputs]
#     522
# --> 523         rval = self._fn_cache[inputs](*args)
#     524
#     525         return rval
#
# /usr/local/lib/python2.7/dist-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     869                     node=self.fn.nodes[self.fn.position_of_error],
#     870                     thunk=thunk,
# --> 871                     storage_map=getattr(self.fn, 'storage_map', None))
#     872             else:
#     873                 # old-style linkers raise their own exceptions
#
# /usr/local/lib/python2.7/dist-packages/theano/gof/link.pyc in raise_with_op(node, thunk, exc_info, storage_map)
#     312         # extra long error message in that case.
#     313         pass
# --> 314     reraise(exc_type, exc_value, exc_trace)
#     315
#     316
#
# /usr/local/lib/python2.7/dist-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     857         t0_fn = time.time()
#     858         try:
# --> 859             outputs = self.fn()
#     860         except Exception:
#     861             if hasattr(self.fn, 'position_of_error'):
#
# /usr/local/lib/python2.7/dist-packages/theano/gof/op.pyc in rval(p, i, o, n)
#     877             # default arguments are stored in the closure of `rval`
#     878             def rval(p=p, i=node_input_storage, o=node_output_storage, n=node):
# --> 879                 r = p(n, [x[0] for x in i], o)
#     880                 for o in node.outputs:
#     881                     compute_map[o][0] = True
#
# /usr/local/lib/python2.7/dist-packages/theano/tensor/subtensor.pyc in perform(self, node, inputs, out_)
#    2158         # TODO: in general, we need to re-pack the inputs into a valid
#    2159         # index, just like subtensor
# -> 2160         out[0] = inputs[0].__getitem__(inputs[1:])
#    2161         if (numpy.__version__ <= '1.6.1' and
#    2162                 out[0].size != numpy.uint32(out[0].size)):
#
# IndexError: index 25 is out of bounds for axis 0 with size 25
# Apply node that caused the error: AdvancedSubtensor(argmax, Join.0, SliceConstant{None, None, None})
# Toposort index: 129
# Inputs types: [TensorType(int64, matrix), TensorType(int64, matrix), <theano.tensor.type_other.SliceType object at 0x7f44ea25a9d0>]
# Inputs shapes: [(25, 50), (2, 819), 'No shapes']
# Inputs strides: [(400, 8), (6552, 8), 'No strides']
# Inputs values: ['not shown', 'not shown', slice(None, None, None)]
# Outputs clients: [[AdvancedSubtensor(AdvancedSubtensor.0, ARange{dtype='int64'}.0, AdvancedSubtensor.0)]]
#
# Backtrace when the node is created:
#   File "<ipython-input-158-80e711c240c2>", line 26, in get_reference_triples
#     _chosen_action_IDs = _decision_ids[_alive_selector,:]
#
# HINT: Use the Theano flag 'exception_verbosity=high' for a debugprint and storage map footprint of this apply node.

# %%
_nn_params = lasagne.layers.get_all_params(_rnn)
_nn_params
# Out:
# [mdp_gru.W_in_to_updategate,
#  mdp_gru.W_hid_to_updategate,
#  mdp_gru.b_updategate,
#  mdp_gru.W_in_to_resetgate,
#  mdp_gru.W_hid_to_resetgate,
#  mdp_gru.b_resetgate,
#  mdp_gru.W_in_to_hidden_update,
#  mdp_gru.W_hid_to_hidden_update,
#  mdp_gru.b_hidden_update]

# %%
#_updates = lasagne.updates.nesterov_momentum(_loss,_nn_params,0.01)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-125-8b921aeec172> in <module>()
# ----> 1 _updates = lasagne.updates.nesterov_momentum(_loss,_nn_params,0.01)
#
# /usr/local/lib/python2.7/dist-packages/lasagne/updates.pyc in nesterov_momentum(loss_or_grads, params, learning_rate, momentum)
#     334     apply_nesterov_momentum : Function applying momentum to updates
#     335     """
# --> 336     updates = sgd(loss_or_grads, params, learning_rate)
#     337     return apply_nesterov_momentum(updates, momentum=momentum)
#     338
#
# /usr/local/lib/python2.7/dist-packages/lasagne/updates.pyc in sgd(loss_or_grads, params, learning_rate)
#     144         A dictionary mapping each parameter to its update expression
#     145     """
# --> 146     grads = get_or_compute_grads(loss_or_grads, params)
#     147     updates = OrderedDict()
#     148
#
# /usr/local/lib/python2.7/dist-packages/lasagne/updates.pyc in get_or_compute_grads(loss_or_grads, params)
#     120         return loss_or_grads
#     121     else:
# --> 122         return theano.grad(loss_or_grads, params)
#     123
#     124
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in grad(cost, wrt, consider_constant, disconnected_inputs, add_names, known_grads, return_disconnected, null_gradients)
#     559
#     560     rval = _populate_grad_dict(var_to_app_to_idx,
# --> 561                                grad_dict, wrt, cost_name)
#     562
#     563     for i in xrange(len(rval)):
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in _populate_grad_dict(var_to_app_to_idx, grad_dict, wrt, cost_name)
#    1322         return grad_dict[var]
#    1323
# -> 1324     rval = [access_grad_cache(elem) for elem in wrt]
#    1325
#    1326     return rval
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_grad_cache(var)
#    1277                     for idx in node_to_idx[node]:
#    1278
# -> 1279                         term = access_term_cache(node)[idx]
#    1280
#    1281                         if not isinstance(term, gof.Variable):
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_term_cache(node)
#     971             inputs = node.inputs
#     972
# --> 973             output_grads = [access_grad_cache(var) for var in node.outputs]
#     974
#     975             # list of bools indicating if each output is connected to the cost
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_grad_cache(var)
#    1277                     for idx in node_to_idx[node]:
#    1278
# -> 1279                         term = access_term_cache(node)[idx]
#    1280
#    1281                         if not isinstance(term, gof.Variable):
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_term_cache(node)
#     971             inputs = node.inputs
#     972
# --> 973             output_grads = [access_grad_cache(var) for var in node.outputs]
#     974
#     975             # list of bools indicating if each output is connected to the cost
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_grad_cache(var)
#    1277                     for idx in node_to_idx[node]:
#    1278
# -> 1279                         term = access_term_cache(node)[idx]
#    1280
#    1281                         if not isinstance(term, gof.Variable):
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_term_cache(node)
#     971             inputs = node.inputs
#     972
# --> 973             output_grads = [access_grad_cache(var) for var in node.outputs]
#     974
#     975             # list of bools indicating if each output is connected to the cost
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_grad_cache(var)
#    1277                     for idx in node_to_idx[node]:
#    1278
# -> 1279                         term = access_term_cache(node)[idx]
#    1280
#    1281                         if not isinstance(term, gof.Variable):
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_term_cache(node)
#     971             inputs = node.inputs
#     972
# --> 973             output_grads = [access_grad_cache(var) for var in node.outputs]
#     974
#     975             # list of bools indicating if each output is connected to the cost
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_grad_cache(var)
#    1277                     for idx in node_to_idx[node]:
#    1278
# -> 1279                         term = access_term_cache(node)[idx]
#    1280
#    1281                         if not isinstance(term, gof.Variable):
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_term_cache(node)
#     971             inputs = node.inputs
#     972
# --> 973             output_grads = [access_grad_cache(var) for var in node.outputs]
#     974
#     975             # list of bools indicating if each output is connected to the cost
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_grad_cache(var)
#    1277                     for idx in node_to_idx[node]:
#    1278
# -> 1279                         term = access_term_cache(node)[idx]
#    1280
#    1281                         if not isinstance(term, gof.Variable):
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_term_cache(node)
#     971             inputs = node.inputs
#     972
# --> 973             output_grads = [access_grad_cache(var) for var in node.outputs]
#     974
#     975             # list of bools indicating if each output is connected to the cost
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_grad_cache(var)
#    1277                     for idx in node_to_idx[node]:
#    1278
# -> 1279                         term = access_term_cache(node)[idx]
#    1280
#    1281                         if not isinstance(term, gof.Variable):
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_term_cache(node)
#     971             inputs = node.inputs
#     972
# --> 973             output_grads = [access_grad_cache(var) for var in node.outputs]
#     974
#     975             # list of bools indicating if each output is connected to the cost
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_grad_cache(var)
#    1277                     for idx in node_to_idx[node]:
#    1278
# -> 1279                         term = access_term_cache(node)[idx]
#    1280
#    1281                         if not isinstance(term, gof.Variable):
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_term_cache(node)
#     971             inputs = node.inputs
#     972
# --> 973             output_grads = [access_grad_cache(var) for var in node.outputs]
#     974
#     975             # list of bools indicating if each output is connected to the cost
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_grad_cache(var)
#    1277                     for idx in node_to_idx[node]:
#    1278
# -> 1279                         term = access_term_cache(node)[idx]
#    1280
#    1281                         if not isinstance(term, gof.Variable):
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_term_cache(node)
#     971             inputs = node.inputs
#     972
# --> 973             output_grads = [access_grad_cache(var) for var in node.outputs]
#     974
#     975             # list of bools indicating if each output is connected to the cost
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_grad_cache(var)
#    1277                     for idx in node_to_idx[node]:
#    1278
# -> 1279                         term = access_term_cache(node)[idx]
#    1280
#    1281                         if not isinstance(term, gof.Variable):
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_term_cache(node)
#     971             inputs = node.inputs
#     972
# --> 973             output_grads = [access_grad_cache(var) for var in node.outputs]
#     974
#     975             # list of bools indicating if each output is connected to the cost
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_grad_cache(var)
#    1277                     for idx in node_to_idx[node]:
#    1278
# -> 1279                         term = access_term_cache(node)[idx]
#    1280
#    1281                         if not isinstance(term, gof.Variable):
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_term_cache(node)
#     971             inputs = node.inputs
#     972
# --> 973             output_grads = [access_grad_cache(var) for var in node.outputs]
#     974
#     975             # list of bools indicating if each output is connected to the cost
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_grad_cache(var)
#    1277                     for idx in node_to_idx[node]:
#    1278
# -> 1279                         term = access_term_cache(node)[idx]
#    1280
#    1281                         if not isinstance(term, gof.Variable):
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_term_cache(node)
#    1111                                 str(g_shape))
#    1112
# -> 1113                 input_grads = node.op.grad(inputs, new_output_grads)
#    1114
#    1115                 if input_grads is None:
#
# /usr/local/lib/python2.7/dist-packages/theano/scan_module/scan_op.pyc in grad(self, inputs, dC_douts)
#    2118                         known_grads[diff_outputs[i]] = dC_dXts[dc_dxts_idx]
#    2119                     dc_dxts_idx += 1
# -> 2120         dC_dinps_t = compute_all_gradients(known_grads)
#    2121
#    2122
#
# /usr/local/lib/python2.7/dist-packages/theano/scan_module/scan_op.pyc in compute_all_gradients(known_grads)
#    2039                         disconnected_inputs='ignore',
#    2040                         return_disconnected='None',
# -> 2041                         null_gradients='return')
#    2042
#    2043             for i in range(len(wrt)):
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in grad(cost, wrt, consider_constant, disconnected_inputs, add_names, known_grads, return_disconnected, null_gradients)
#     559
#     560     rval = _populate_grad_dict(var_to_app_to_idx,
# --> 561                                grad_dict, wrt, cost_name)
#     562
#     563     for i in xrange(len(rval)):
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in _populate_grad_dict(var_to_app_to_idx, grad_dict, wrt, cost_name)
#    1322         return grad_dict[var]
#    1323
# -> 1324     rval = [access_grad_cache(elem) for elem in wrt]
#    1325
#    1326     return rval
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_grad_cache(var)
#    1277                     for idx in node_to_idx[node]:
#    1278
# -> 1279                         term = access_term_cache(node)[idx]
#    1280
#    1281                         if not isinstance(term, gof.Variable):
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_term_cache(node)
#    1194                                         ' returned an integer-valued variable.'
#    1195                                         ' (Input index %d, dtype %s)' % (
# -> 1196                                             i, term.type.dtype))
#    1197
#    1198                     if only_connected_to_nan[i]:
#
# TypeError: MaxAndArgmax.grad illegally  returned an integer-valued variable. (Input index 0, dtype int8)

# %%
T.grad(_loss,_rnn.W_in_to_updategate,consider_constant=TGrad_ignore_list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-143-825be601edf1> in <module>()
# ----> 1 T.grad(_loss,_rnn.W_in_to_updategate,consider_constant=TGrad_ignore_list)
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in grad(cost, wrt, consider_constant, disconnected_inputs, add_names, known_grads, return_disconnected, null_gradients)
#     559
#     560     rval = _populate_grad_dict(var_to_app_to_idx,
# --> 561                                grad_dict, wrt, cost_name)
#     562
#     563     for i in xrange(len(rval)):
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in _populate_grad_dict(var_to_app_to_idx, grad_dict, wrt, cost_name)
#    1322         return grad_dict[var]
#    1323
# -> 1324     rval = [access_grad_cache(elem) for elem in wrt]
#    1325
#    1326     return rval
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_grad_cache(var)
#    1277                     for idx in node_to_idx[node]:
#    1278
# -> 1279                         term = access_term_cache(node)[idx]
#    1280
#    1281                         if not isinstance(term, gof.Variable):
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_term_cache(node)
#     971             inputs = node.inputs
#     972
# --> 973             output_grads = [access_grad_cache(var) for var in node.outputs]
#     974
#     975             # list of bools indicating if each output is connected to the cost
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_grad_cache(var)
#    1277                     for idx in node_to_idx[node]:
#    1278
# -> 1279                         term = access_term_cache(node)[idx]
#    1280
#    1281                         if not isinstance(term, gof.Variable):
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_term_cache(node)
#     971             inputs = node.inputs
#     972
# --> 973             output_grads = [access_grad_cache(var) for var in node.outputs]
#     974
#     975             # list of bools indicating if each output is connected to the cost
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_grad_cache(var)
#    1277                     for idx in node_to_idx[node]:
#    1278
# -> 1279                         term = access_term_cache(node)[idx]
#    1280
#    1281                         if not isinstance(term, gof.Variable):
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_term_cache(node)
#     971             inputs = node.inputs
#     972
# --> 973             output_grads = [access_grad_cache(var) for var in node.outputs]
#     974
#     975             # list of bools indicating if each output is connected to the cost
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_grad_cache(var)
#    1277                     for idx in node_to_idx[node]:
#    1278
# -> 1279                         term = access_term_cache(node)[idx]
#    1280
#    1281                         if not isinstance(term, gof.Variable):
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_term_cache(node)
#     971             inputs = node.inputs
#     972
# --> 973             output_grads = [access_grad_cache(var) for var in node.outputs]
#     974
#     975             # list of bools indicating if each output is connected to the cost
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_grad_cache(var)
#    1277                     for idx in node_to_idx[node]:
#    1278
# -> 1279                         term = access_term_cache(node)[idx]
#    1280
#    1281                         if not isinstance(term, gof.Variable):
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_term_cache(node)
#     971             inputs = node.inputs
#     972
# --> 973             output_grads = [access_grad_cache(var) for var in node.outputs]
#     974
#     975             # list of bools indicating if each output is connected to the cost
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_grad_cache(var)
#    1277                     for idx in node_to_idx[node]:
#    1278
# -> 1279                         term = access_term_cache(node)[idx]
#    1280
#    1281                         if not isinstance(term, gof.Variable):
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_term_cache(node)
#     971             inputs = node.inputs
#     972
# --> 973             output_grads = [access_grad_cache(var) for var in node.outputs]
#     974
#     975             # list of bools indicating if each output is connected to the cost
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_grad_cache(var)
#    1277                     for idx in node_to_idx[node]:
#    1278
# -> 1279                         term = access_term_cache(node)[idx]
#    1280
#    1281                         if not isinstance(term, gof.Variable):
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_term_cache(node)
#     971             inputs = node.inputs
#     972
# --> 973             output_grads = [access_grad_cache(var) for var in node.outputs]
#     974
#     975             # list of bools indicating if each output is connected to the cost
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_grad_cache(var)
#    1277                     for idx in node_to_idx[node]:
#    1278
# -> 1279                         term = access_term_cache(node)[idx]
#    1280
#    1281                         if not isinstance(term, gof.Variable):
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_term_cache(node)
#     971             inputs = node.inputs
#     972
# --> 973             output_grads = [access_grad_cache(var) for var in node.outputs]
#     974
#     975             # list of bools indicating if each output is connected to the cost
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_grad_cache(var)
#    1277                     for idx in node_to_idx[node]:
#    1278
# -> 1279                         term = access_term_cache(node)[idx]
#    1280
#    1281                         if not isinstance(term, gof.Variable):
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_term_cache(node)
#     971             inputs = node.inputs
#     972
# --> 973             output_grads = [access_grad_cache(var) for var in node.outputs]
#     974
#     975             # list of bools indicating if each output is connected to the cost
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_grad_cache(var)
#    1277                     for idx in node_to_idx[node]:
#    1278
# -> 1279                         term = access_term_cache(node)[idx]
#    1280
#    1281                         if not isinstance(term, gof.Variable):
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_term_cache(node)
#     971             inputs = node.inputs
#     972
# --> 973             output_grads = [access_grad_cache(var) for var in node.outputs]
#     974
#     975             # list of bools indicating if each output is connected to the cost
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_grad_cache(var)
#    1277                     for idx in node_to_idx[node]:
#    1278
# -> 1279                         term = access_term_cache(node)[idx]
#    1280
#    1281                         if not isinstance(term, gof.Variable):
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_term_cache(node)
#     971             inputs = node.inputs
#     972
# --> 973             output_grads = [access_grad_cache(var) for var in node.outputs]
#     974
#     975             # list of bools indicating if each output is connected to the cost
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_grad_cache(var)
#    1277                     for idx in node_to_idx[node]:
#    1278
# -> 1279                         term = access_term_cache(node)[idx]
#    1280
#    1281                         if not isinstance(term, gof.Variable):
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_term_cache(node)
#    1111                                 str(g_shape))
#    1112
# -> 1113                 input_grads = node.op.grad(inputs, new_output_grads)
#    1114
#    1115                 if input_grads is None:
#
# /usr/local/lib/python2.7/dist-packages/theano/scan_module/scan_op.pyc in grad(self, inputs, dC_douts)
#    2118                         known_grads[diff_outputs[i]] = dC_dXts[dc_dxts_idx]
#    2119                     dc_dxts_idx += 1
# -> 2120         dC_dinps_t = compute_all_gradients(known_grads)
#    2121
#    2122
#
# /usr/local/lib/python2.7/dist-packages/theano/scan_module/scan_op.pyc in compute_all_gradients(known_grads)
#    2039                         disconnected_inputs='ignore',
#    2040                         return_disconnected='None',
# -> 2041                         null_gradients='return')
#    2042
#    2043             for i in range(len(wrt)):
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in grad(cost, wrt, consider_constant, disconnected_inputs, add_names, known_grads, return_disconnected, null_gradients)
#     559
#     560     rval = _populate_grad_dict(var_to_app_to_idx,
# --> 561                                grad_dict, wrt, cost_name)
#     562
#     563     for i in xrange(len(rval)):
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in _populate_grad_dict(var_to_app_to_idx, grad_dict, wrt, cost_name)
#    1322         return grad_dict[var]
#    1323
# -> 1324     rval = [access_grad_cache(elem) for elem in wrt]
#    1325
#    1326     return rval
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_grad_cache(var)
#    1277                     for idx in node_to_idx[node]:
#    1278
# -> 1279                         term = access_term_cache(node)[idx]
#    1280
#    1281                         if not isinstance(term, gof.Variable):
#
# /usr/local/lib/python2.7/dist-packages/theano/gradient.pyc in access_term_cache(node)
#    1194                                         ' returned an integer-valued variable.'
#    1195                                         ' (Input index %d, dtype %s)' % (
# -> 1196                                             i, term.type.dtype))
#    1197
#    1198                     if only_connected_to_nan[i]:
#
# TypeError: MaxAndArgmax.grad illegally  returned an integer-valued variable. (Input index 0, dtype int8)

# %%
_rewards,_isalive,_attempts,_decisions,_activations = get_feedback(
    _prediction,dependencies=env.dependencies,end_code=25)
feedback = theano.function([],[_rewards,_isalive,_attempts,_decisions,_activations])

rw,alive,attempts,decisions,activations = feedback()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-141-990d41913387> in <module>()
#       1 _rewards,_isalive,_attempts,_decisions,_activations = get_feedback(
# ----> 2     _prediction,dependencies=env.dependencies,end_code=25)
#       3 feedback = theano.function([],[_rewards,_isalive,_attempts,_decisions,_activations])
#       4
#       5 rw,alive,attempts,decisions,activations = feedback()
#
# <ipython-input-136-9c0844f2c567> in get_feedback(_prediction, dependencies, t0, end_code, strict)
#      78                                             outputs_info,
#      79                                             non_sequences,
# ---> 80                                             strict=True)[0]
#      81     attempted_ext = attempted_ext[-1]
#      82
#
# /usr/local/lib/python2.7/dist-packages/theano/scan_module/scan.pyc in scan(fn, sequences, outputs_info, non_sequences, n_steps, truncate_gradient, go_backwards, mode, name, profile, allow_gc, strict)
#     743     # and outputs that needs to be separated
#     744
# --> 745     condition, outputs, updates = scan_utils.get_updates_and_outputs(fn(*args))
#     746     if condition is not None:
#     747         as_while = True
#
# <ipython-input-136-9c0844f2c567> in reward_computation_step(decision_code, fields_attempted_ext, last_reward, session_active, event_arr_ext, *args)
#      68
#      69
# ---> 70         fields_attempted_now_ext = fields_attempted_ext | decision_i
#      71
#      72         #current_reward
#
# NameError: global name 'decision_i' is not defined

# %%
_pre
# Out:
# (50, 25, 26)

# %%
_=plt.hist(activations.ravel(),bins = 100)

# %%
theano.printing.pydotprint(_prediction,"graph.png")
# Out:
# The output file is available at graph.png
